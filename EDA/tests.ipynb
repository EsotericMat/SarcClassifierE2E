# %%
import ollama

def embedd_text(txt):
    response = ollama.embed(model="nomic-embed-text", input=txt)
    embeddings = response["embeddings"]
    return embeddings[0]

# %%
a = embedd_text('Why are you gay?')

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 768

# %%
a
# Out:
# [[0.026327409,
#   0.049900983,
#   -0.11159186,
#   0.023037905,
#   0.02903694,
#   0.08679328,
#   0.009302007,
#   -0.049583353,
#   -0.0337099,
#   -0.043381635,
#   -0.05297867,
#   0.12723711,
#   0.04198947,
#   -0.002322798,
#   -0.029146781,
#   0.004319371,
#   -0.026671369,
#   -0.028215464,
#   0.023540596,
#   -0.020441208,
#   -0.097529225,
#   -0.019895876,
#   -0.019647717,
#   -0.043672133,
#   0.11233254,
#   0.013616834,
#   0.02420333,
#   0.04801299,
#   -0.050161306,
#   0.037124284,
#   0.0046467516,
#   0.013403076,
#   -0.0019558235,
#   0.021492973,
#   -0.03421454,
#   -0.04746479,
#   -0.0317085,
#   -0.022197112,
#   0.039168894,
#   -0.008423908,
#   0.012591804,
#   -0.03189621,
#   -0.02661268,
#   -0.03874415,
#   0.032038435,
#   0.00040436912,
#   0.008016119,
#   0.002275267,
#   0.0624767,
#   -0.08492025,
#   -0.0018571774,
#   -0.03905106,
#   -0.024932437,
#   -0.050514128,
#   0.09204842,
#   -0.030431634,
#   0.020520044,
#   0.0065313005,
# ...
